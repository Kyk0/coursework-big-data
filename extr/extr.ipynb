# %% [markdown]
# ## Extra Exercise

# %% [markdown]
# ## Kyrylo Kolesnichenko
#
# ## 153371848

# %% [markdown]
# ### Task E.1.a
# E.1.a (3 points)
# Read carefully section 4.4 in the book and solve Exercise 4.4.1. What is the estimate of the number of
# distinct elements in the given stream
# 1) for each of the three hash functions separately?
# 2) for the three hash functions if they are combined by the mean operator?

# %% [markdown]
# ![image](img.png)

# %% [markdown]
# In order to solve E.1 we will first do Exercise 4.4.1 and then estimate the number of distinct elements for the combined hash functions as well.
#
# In E.4.4.1, we are given three hash functions and asked to estimate the number of distinct elements. First, we apply each function to the values from the stream, then convert the results to 5-bit binary, then count the number of trailing zeros for each value, and find  max. After that, we take 2 to the power of that maximum to get the estimate.
#
# By the end, we calculate the final combined estimate taking the mean of the three individual estimates.

# %%
stream = [3, 1, 4, 1, 5, 9, 2, 6, 5]

hash_funcs = {
    'h1': lambda x: (2 * x + 1) % 32,
    'h2': lambda x: (3 * x + 7) % 32,
    'h3': lambda x: (4 * x) % 32
}

results = {}

for name, func in hash_funcs.items():
    values = [func(x) for x in stream]
    max_zeros = 0
    for val in values:
        count = 0
        for bit in bin(val)[::-1]:
            if bit == '1':
                break
            if bit == '0':
                count += 1
        if count > max_zeros:
            max_zeros = count
    estimate = 2 ** max_zeros
    results[name] = {
        'hashed': values,
        'max_zeros': max_zeros,
        'estimate': estimate
    }

for name in results:
    print(name)
    print("  Hashed values:", results[name]['hashed'])
    print("  Max trailing zeros:", results[name]['max_zeros'])
    print("  Estimate:", results[name]['estimate'], "\n")

mean_estimate = sum(r['estimate'] for r in results.values()) / 3
print(f"Combined mean estimate: {mean_estimate:.2f}")
# Out:
# h1
#   Hashed values: [7, 3, 9, 3, 11, 19, 5, 13, 11]
#   Max trailing zeros: 0
#   Estimate: 1
#
# h2
#   Hashed values: [16, 10, 19, 10, 22, 2, 13, 25, 22]
#   Max trailing zeros: 4
#   Estimate: 16
#
# h3
#   Hashed values: [12, 4, 16, 4, 20, 4, 8, 24, 20]
#   Max trailing zeros: 4
#   Estimate: 16
#
# Combined mean estimate: 11.00

# %% [markdown]
# ### Task E.1.a

# %% [markdown]
# Extend Exercise 4.4.1 by creating a sequence of 100 integers so that
# 1) there are 8 distinct numbers
# 2) there are 3 distinct numbers
# Generate 50 hash functions according to the rule ℎ(𝑥) = (𝑎𝑥 + 𝑏) 𝑚𝑜𝑑 32 by generating 50 sets of
# integer values for 𝑎 and 𝑏. Calculate the 100 x 50 hash values for both streams 1) and 2) above.
# Calculate then the corresponding 50 estimates of distinct elements in the two streams for each hash
# function. Finally combine the 50 estimates for each stream in the following three ways:
# a) by taking the mean over the hash function results
# b) by taking the median over the hash function results
# c) by dividing the 50 results into 5 groups of 10 estimates, averaging over each group and then
# taking median over these averages.

# %% [markdown]
# Now E.1.b
#
# So we're first creating the streams as said in the task and generating hash functions by formula h(x) = (a * x + b) mod 32 with random a and b
#
# Next, we define a function that applies all hash functions to the stream and calculates its estimate by hashing values, converting them to binary and then taking 2 to the power of the maximum count
#
# By the end we using this function on the streams and calculating the estimates for mean, median and dividing the estimates into 5 groups of 10, averaging each and then taking the median of 5 group averages.

# %%
import random
import statistics

stream_8 = [1, 2, 3, 4, 5, 6, 7, 8] * 12 + [1, 2, 3, 4]
stream_3 = [10, 20, 30] * 33 + [10]

params = [(random.randint(1, 31), random.randint(0, 31)) for _ in range(50)]
hash_functions = [lambda x, a=a, b=b: (a * x + b) % 32 for a, b in params]

def run_estimate(stream, hash_functions):
    estimates = []
    for h in hash_functions:
        hashed_values = [h(x) for x in stream]
        max_trailing_zeros = 0
        for value in hashed_values:
            if value == 0:
                zeros = 5
            else:
                zeros = 0
                for bit in bin(value)[2:][::-1]:
                    if bit == '1':
                        break
                    if bit == '0':
                        zeros += 1
            if zeros > max_trailing_zeros:
                max_trailing_zeros = zeros
        estimates.append(2 ** max_trailing_zeros)
    return estimates

estimates_8 = run_estimate(stream_8, hash_functions)
estimates_3 = run_estimate(stream_3, hash_functions)

groups_8 = [sum(estimates_8[i:i+10]) / 10 for i in range(0, 50, 10)]
groups_3 = [sum(estimates_3[i:i+10]) / 10 for i in range(0, 50, 10)]

print("Stream with 8 distinct values:")
print("Mean:", round(sum(estimates_8) / 50, 2))
print("Median:", round(statistics.median(estimates_8), 2))
print("Group median:", round(statistics.median(groups_8), 2))

print("\nStream with 3 distinct values:")
print("Mean:", round(sum(estimates_3) / 50, 2))
print("Median:", round(statistics.median(estimates_3), 2))
print("Group median:", round(statistics.median(groups_3), 2))
# Out:
# Stream with 8 distinct values:
# Mean: 14.6
# Median: 8.0
# Group median: 13.0
#
# Stream with 3 distinct values:
# Mean: 6.36
# Median: 2.0
# Group median: 6.4
